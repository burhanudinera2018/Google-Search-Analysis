# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Data Analytics Jobs"])
data = trends.interest_by_region()
data = data.sort_values(by="Data Analytics Jobs", ascending=False)
data = data.head(10)
print(data)
# Out:
#                       Data Analytics Jobs
# geoName
# Singapore                             100
# Ireland                                75
# Kenya                                  57
# India                                  49
# Nigeria                                45
# United Arab Emirates                   36
# United States                          36
# Canada                                 33
# Pakistan                               29
# Sri Lanka                              29

# %%
data.reset_index().plot(x="geoName", 
                        y="Data Analytics Jobs", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Data Analytics Jobs'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Data Analytics Jobs'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Data Analytics Jobs', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
